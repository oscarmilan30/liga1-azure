# %%
import bootstrap
from util.utils_liga1 import get_entity_data,setup_adls
setup_adls()

# %%
# Leer entidad equipos (u otra)
df_equipos = get_entity_data("equipos")

if df_equipos:
    print("Registros leídos:", df_equipos.count())
    display(df_equipos)
