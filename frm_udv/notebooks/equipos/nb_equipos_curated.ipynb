# %%
import env_setup
from utils_liga1 import setup_adls,get_dbutils,generar_udv_json,get_entity_data,generar_udv_json

import env_setup
from pyspark.sql import SparkSession
from utils_liga1 import setup_adls, get_dbutils

# ----------------------------------------------------------
# CONFIGURACIÓN DE ADLS Y SPARK
# ----------------------------------------------------------
spark = SparkSession.builder.getOrCreate()
setup_adls()
dbutils = get_dbutils()

# %%
# Leer entidad equipos (u otra)
df_udv_equipos = generar_udv_json("equipos") 
display(df_udv_equipos)
