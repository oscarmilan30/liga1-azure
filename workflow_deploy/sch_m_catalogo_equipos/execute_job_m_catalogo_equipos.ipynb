# %%
from env_setup import *
import requests
import json
from utils_liga1 import get_dbutils

spark = SparkSession.builder.getOrCreate()
dbutils = get_dbutils()

# Parámetros
DATABRICKS_INSTANCE = "https://adb-1676851685217423.3.azuredatabricks.net"
TOKEN = dbutils.secrets.get(scope="secretliga1", key="databricks-token")

# Carga tu JSON local
with open("sch_m_catalogo_equipos.json", "r") as f:
    job_definition = json.load(f)

# Endpoint para crear job
url = f"{DATABRICKS_INSTANCE}/api/2.1/jobs/create"

headers = {
    "Authorization": f"Bearer {TOKEN}",
    "Content-Type": "application/json"
}

response = requests.post(url, headers=headers, json=job_definition)

print(response.status_code)
print(response.text)
